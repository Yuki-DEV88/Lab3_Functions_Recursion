# %%
# [CELL 1] Student Configuration

LAST_NAME = "Cardenas" # Replace with your surname
STUDENT_ID = "TUPM-26-1258" # Replace with your ID

SEED_DIGIT = int(STUDENT_ID[-1])
ID_SUM = sum(int(d) for d in STUDENT_ID if d.isdigit())
NAME_LENGTH = len(LAST_NAME)

print("Student", LAST_NAME)
print("Seed Digit", SEED_DIGIT)
print("Digit Sum:", ID_SUM)
print("Surname Length:", NAME_LENGTH)
# Out:
# Student Cardenas
# Seed Digit 8
# Digit Sum: 24
# Surname Length: 8

# %%
# [CELL 2] FUNCTIONAL ESCAPULATION

def greet():
    print("="* 40)
    print((f"System Initialized for {LAST_NAME}"))
    print("=" * 40)

def identity_code():
    code = SEED_DIGIT * NAME_LENGTH
    return code
greet()
print("Identity Code:", identity_code())
# Out:
# ========================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       7
#       8 def identity_code():
#       9     code = SEED_DIGIT * NAME_LENGTH
#      10     return code
# ---> 11 greet()
#      12 print("Identity Code:", identity_code())
#
# Cell In[7], line 5, in greet()
#       3 def greet():
#       4     print("="* 40)
# ----> 5     print((f"System Initialized for {LAST_NAME}"))
#       6     print("=" * 40)
#
# NameError: name 'LAST_NAME' is not defined

# %%
# [CELL 3 LEGB VALIDATION]

global_value = ID_SUM

def scope_test():
    global_value = SEED_DIGIT
    print("Inside Function:", global_value)
    
scope_test()
print("Outside Function:", global_value)
# Out:
# Inside Function: 8
# Outside Function: 24

# %%
# [CELL 4] PARAMETRIC PROCESSING

def user_summary(title, *scores, **info):
    print(f"=== {title} ===")

    total = sum(scores)
    average = total / len(scores)

    print("Scores:", scores)
    print("Total:", total)
    print("Average", average)

    for k, v in info.items():
        print((f"{k}: {v}"))

    return average

avg = user_summary(
    f"{LAST_NAME} Academic Report",
    SEED_DIGIT * 10,
    ID_SUM % 100,
    NAME_LENGTH * 5,
    id=STUDENT_ID,
    Surname=LAST_NAME
)
# Out:
# === Cardenas Academic Report ===
# Scores: (80, 24, 40)
# Total: 144
# Average 48.0
# id: TUPM-26-1258
# Surname: Cardenas
